# %% [markdown]
# # Advent of Code 2021 - Day 16

# %% [markdown]
# ## File Input

# %%
input = open('./input.txt', "r")
transmission = input.read()
input.close()

test_strings = ["D2FE28", "38006F45291200", "EE00D40C823060", "8A004A801A8002F478", "620080001611562C8802118E34", "C0015000016115A2E0802F182340", "A0016C880162017C3686B18A3D4780"]

# %% [markdown]
# ## Part 1

# %%
hex_to_bin = {
    "0": "0000",
    "1": "0001",
    "2": "0010",
    "3": "0011",
    "4": "0100",
    "5": "0101",
    "6": "0110",
    "7": "0111",
    "8": "1000",
    "9": "1001",
    "A": "1010",
    "B": "1011",
    "C": "1100",
    "D": "1101",
    "E": "1110",
    "F": "1111"
}

def convert_hex_to_binary(hex_format):
    return "".join([hex_to_bin[char] for char in hex_format])

def get_sub_packet(binary_transmission):
    packet_version = int(binary_transmission[:3], 2)
    packet_type_id = int(binary_transmission[3:6], 2)
    is_literal_value = packet_type_id == 4
    pointer = 6
        
    if is_literal_value:        
        # skip over values of literal number
        while binary_transmission[pointer] == "1":
            pointer += 5
        pointer += 5
        
        return binary_transmission[:pointer], pointer
    else:
        length_type_id = binary_transmission[pointer]
        pointer += 1
                        
        if length_type_id == "0":  # length is 15-bit number representing number of bits in sub-packets
            sub_packet_length = int(binary_transmission[pointer:pointer+15], 2)
            pointer += 15
            
            return binary_transmission[:pointer+sub_packet_length], pointer+sub_packet_length
        else: # length is 11-bit number representing number of sub-packets
            num_sub_packets = int(binary_transmission[pointer:pointer+11], 2)
            pointer += 11
            
            subpacket = binary_transmission[:pointer]
            
            for _ in range(num_sub_packets):
                new_sub, new_idx = get_sub_packet(binary_transmission[pointer:])
                subpacket += new_sub
                pointer += new_idx
                
            return subpacket, pointer

def get_version_sum(binary_transmission):
    if len(binary_transmission) <= 7:
        return 0
    
    packet_version = int(binary_transmission[:3], 2)
    packet_type_id = int(binary_transmission[3:6], 2)
    is_literal_value = packet_type_id == 4
    
    version_sum = packet_version
    pointer = 6
        
    if is_literal_value:        
        literal_value = ""
        
        # skip over values of literal number
        while binary_transmission[pointer] == "1":
            literal_value += binary_transmission[pointer+1:pointer+5]
            pointer += 5
        literal_value += binary_transmission[pointer+1:pointer+5]
        pointer += 5
        
        literal_value = int(literal_value, 2)        
        print("literal ", f"version {version_sum}", f"literal value {literal_value}")
                
        return version_sum + get_version_sum(binary_transmission[pointer:])
    else:
        length_type_id = binary_transmission[pointer]
        pointer += 1
        
        print("operator", f"version {version_sum}", f"length type id {length_type_id}")
                
        if length_type_id == "0":  # length is 15-bit number representing number of bits in sub-packets
            sub_packet_length = int(binary_transmission[pointer:pointer+15], 2)
            pointer += 15
                        
            # now need to get version sum for all subpackets, which will take up the next sub_packet_length bits
            return version_sum + get_version_sum(binary_transmission[pointer:pointer+sub_packet_length]) + get_version_sum(binary_transmission[pointer+sub_packet_length:])

        else: # length is 11-bit number representing number of sub-packets
            num_sub_packets = int(binary_transmission[pointer:pointer+11], 2)
            pointer += 11
                                                
            for _ in range(num_sub_packets):
                subpacket, sub_pointer = get_sub_packet(binary_transmission[pointer:])
                version_sum += get_version_sum(subpacket)
                pointer += sub_pointer
                
            return version_sum + get_version_sum(binary_transmission[pointer:])

get_version_sum(convert_hex_to_binary(transmission))
# Out:
# operator version 7 length type id 1
# operator version 0 length type id 1
# literal  version 5 literal value 1161
# operator version 3 length type id 1
# operator version 5 length type id 0
# literal  version 7 literal value 2
# literal  version 6 literal value 4
# literal  version 7 literal value 13
# operator version 3 length type id 1
# literal  version 2 literal value 6
# literal  version 5 literal value 6
# literal  version 4 literal value 3
# operator version 5 length type id 1
# literal  version 3 literal value 5250146
# operator version 7 length type id 1
# literal  version 5 literal value 246310804
# literal  version 1 literal value 246310804
# operator version 7 length type id 0
# operator version 6 length type id 1
# literal  version 4 literal value 4401420
# literal  version 4 literal value 55853
# literal  version 1 literal value 6
# literal  version 4 literal value 3759
# operator version 4 length type id 1
# operator version 2 length type id 1
# operator version 0 length type id 1
# operator version 0 length type id 1
# operator version 1 length type id 0
# operator version 1 length type id 1
# operator version 7 length type id 0
# operator version 2 length type id 1
# operator version 5 length type id 0
# operator version 6 length type id 0
# operator version 0 length type id 1
# operator version 4 length type id 0
# operator version 2 length type id 0
# operator version 2 length type id 1
# operator version 6 length type id 0
# operator version 0 length type id 1
# operator version 4 length type id 0
# operator version 4 length type id 0
# operator version 2 length type id 0
# operator version 0 length type id 0
# literal  version 0 literal value 210
# operator version 4 length type id 1
# literal  version 5 literal value 221698353
# literal  version 0 literal value 12235055
# literal  version 7 literal value 5985701
# literal  version 5 literal value 993960
# literal  version 0 literal value 562644
# operator version 5 length type id 0
# literal  version 2 literal value 2527
# literal  version 0 literal value 53
# literal  version 2 literal value 3749816546
# operator version 6 length type id 1
# literal  version 0 literal value 33
# literal  version 2 literal value 118
# literal  version 7 literal value 5
# literal  version 1 literal value 200
# literal  version 1 literal value 111
# operator version 5 length type id 1
# literal  version 6 literal value 15
# literal  version 4 literal value 1
# literal  version 6 literal value 1534196055
# operator version 4 length type id 1
# operator version 7 length type id 1
# literal  version 5 literal value 121
# literal  version 0 literal value 3640
# literal  version 7 literal value 14342924
# operator version 7 length type id 0
# literal  version 5 literal value 57619135
# operator version 4 length type id 0
# operator version 5 length type id 1
# literal  version 0 literal value 3
# literal  version 2 literal value 5
# literal  version 0 literal value 4
# operator version 6 length type id 0
# literal  version 5 literal value 7
# literal  version 1 literal value 11
# literal  version 4 literal value 3
# operator version 1 length type id 1
# literal  version 1 literal value 16652
# operator version 3 length type id 1
# literal  version 3 literal value 202
# literal  version 5 literal value 216
# literal  version 6 literal value 247
# literal  version 3 literal value 228
# operator version 5 length type id 0
# literal  version 4 literal value 51
# operator version 4 length type id 1
# literal  version 4 literal value 5309559
# literal  version 2 literal value 242
# literal  version 5 literal value 5058445
# operator version 7 length type id 1
# literal  version 1 literal value 111
# literal  version 2 literal value 160
# operator version 6 length type id 1
# literal  version 6 literal value 69
# operator version 1 length type id 0
# literal  version 4 literal value 47728
# literal  version 0 literal value 47728
# operator version 4 length type id 0
# literal  version 6 literal value 46
# operator version 5 length type id 1
# literal  version 0 literal value 9
# literal  version 3 literal value 5788547
# operator version 3 length type id 1
# operator version 3 length type id 0
# literal  version 1 literal value 13750614
# literal  version 7 literal value 63219915833
# literal  version 3 literal value 1682243705
# operator version 2 length type id 0
# literal  version 0 literal value 25033
# operator version 3 length type id 1
# literal  version 7 literal value 147
# literal  version 0 literal value 147
# literal  version 4 literal value 46957
# operator version 6 length type id 0
# literal  version 2 literal value 163
# literal  version 1 literal value 15872
# operator version 6 length type id 1
# operator version 5 length type id 0
# operator version 4 length type id 0
# literal  version 6 literal value 3
# literal  version 4 literal value 12
# literal  version 3 literal value 5
# operator version 7 length type id 1
# literal  version 5 literal value 6
# literal  version 0 literal value 12
# literal  version 6 literal value 6
# literal  version 4 literal value 220
# operator version 3 length type id 1
# literal  version 7 literal value 176
# operator version 7 length type id 1
# literal  version 2 literal value 72409
# literal  version 3 literal value 26342
# operator version 1 length type id 1
# literal  version 2 literal value 848
# literal  version 4 literal value 856
# literal  version 5 literal value 428489
# literal  version 3 literal value 1008
# literal  version 6 literal value 3894
# literal  version 4 literal value 12
# operator version 4 length type id 1
# literal  version 0 literal value 7722
# literal  version 7 literal value 787
# literal  version 3 literal value 14984475
# literal  version 4 literal value 447786
# operator version 7 length type id 0
# operator version 2 length type id 0
# literal  version 7 literal value 79
# literal  version 6 literal value 79
# literal  version 0 literal value 1035635
# operator version 3 length type id 0
# operator version 5 length type id 1
# literal  version 7 literal value 6
# literal  version 5 literal value 9
# literal  version 6 literal value 7
# operator version 7 length type id 0
# literal  version 6 literal value 5
# literal  version 4 literal value 12
# literal  version 2 literal value 8
# operator version 4 length type id 0
# literal  version 1 literal value 7
# literal  version 7 literal value 9
# literal  version 3 literal value 9
# operator version 4 length type id 0
# literal  version 1 literal value 1610
# operator version 7 length type id 1
# literal  version 1 literal value 273381
# literal  version 7 literal value 80749
# operator version 7 length type id 0
# literal  version 7 literal value 629
# operator version 6 length type id 1
# literal  version 2 literal value 172
# literal  version 7 literal value 139
# operator version 1 length type id 1
# operator version 3 length type id 0
# literal  version 1 literal value 10
# literal  version 0 literal value 6242768568
# literal  version 5 literal value 189
# operator version 3 length type id 0
# literal  version 7 literal value 1162
# literal  version 5 literal value 2395511720
# operator version 6 length type id 1
# literal  version 4 literal value 235
# literal  version 7 literal value 179
# literal  version 1 literal value 131
# operator version 4 length type id 1
# literal  version 3 literal value 494786039859
# literal  version 6 literal value 151573
# literal  version 4 literal value 32919
# literal  version 2 literal value 7
# operator version 0 length type id 1
# literal  version 6 literal value 24812
# operator version 3 length type id 1
# operator version 6 length type id 1
# operator version 1 length type id 0
# literal  version 4 literal value 3
# literal  version 0 literal value 3
# literal  version 4 literal value 15
# operator version 1 length type id 1
# literal  version 0 literal value 11
# literal  version 4 literal value 6
# literal  version 5 literal value 9
# literal  version 2 literal value 1672
# operator version 5 length type id 1
# operator version 5 length type id 1
# literal  version 0 literal value 12
# literal  version 7 literal value 4
# literal  version 4 literal value 13
# operator version 0 length type id 0
# literal  version 7 literal value 14
# literal  version 3 literal value 4
# literal  version 2 literal value 13
# operator version 6 length type id 1
# literal  version 3 literal value 15
# literal  version 7 literal value 10
# literal  version 7 literal value 14
# operator version 7 length type id 1
# literal  version 4 literal value 1714
# operator version 2 length type id 0
# literal  version 4 literal value 12776488
# literal  version 4 literal value 12776488
# literal  version 5 literal value 1924485091
# operator version 5 length type id 1
# literal  version 2 literal value 162
# operator version 6 length type id 1
# literal  version 0 literal value 183
# literal  version 2 literal value 184
# literal  version 3 literal value 470674
# literal  version 0 literal value 3
# literal  version 4 literal value 11661682
# literal  version 0 literal value 3126
# operator version 0 length type id 1
# operator version 1 length type id 1
# literal  version 4 literal value 3941
# literal  version 6 literal value 19411949671
# literal  version 3 literal value 59
# operator version 4 length type id 1
# literal  version 4 literal value 3593230329
# literal  version 0 literal value 8
# literal  version 2 literal value 5
# operator version 6 length type id 0
# literal  version 4 literal value 42
# literal  version 7 literal value 36
# literal  version 1 literal value 2
# literal  version 6 literal value 508665266753
# operator version 1 length type id 1
# literal  version 5 literal value 11
# literal  version 6 literal value 14
# operator version 1 length type id 0
# operator version 1 length type id 1
# operator version 2 length type id 0
# literal  version 4 literal value 10
# literal  version 6 literal value 4
# literal  version 4 literal value 9
# operator version 5 length type id 1
# literal  version 2 literal value 2
# literal  version 3 literal value 10
# literal  version 3 literal value 13
# literal  version 2 literal value 235
# operator version 3 length type id 0
# literal  version 4 literal value 466695
# literal  version 5 literal value 281
# literal  version 6 literal value 622270
# literal  version 4 literal value 4
# literal  version 5 literal value 229
# 984

# %% [markdown]
# ## Part 2

# %%
from math import prod

def parse_packet(binary_transmission):
    if len(binary_transmission) <= 7:
        return []
    
    packet_version = int(binary_transmission[:3], 2)
    packet_type_id = int(binary_transmission[3:6], 2)
    is_literal_value = packet_type_id == 4
    
    version_sum = packet_version
    pointer = 6
        
    if is_literal_value:        
        literal_value = ""
        
        # skip over values of literal number
        while binary_transmission[pointer] == "1":
            literal_value += binary_transmission[pointer+1:pointer+5]
            pointer += 5
        literal_value += binary_transmission[pointer+1:pointer+5]
        pointer += 5
        
        literal_value = int(literal_value, 2)        
        print("literal ", f"version {version_sum}", f"literal value {literal_value}")
                
        return [literal_value] + parse_packet(binary_transmission[pointer:])
    else:
        length_type_id = binary_transmission[pointer]
        pointer += 1
        
        print("operator", f"version {version_sum}", f"length type id {length_type_id}")
        
        subpackets = []
                
        if length_type_id == "0":  # length is 15-bit number representing number of bits in sub-packets
            sub_packet_length = int(binary_transmission[pointer:pointer+15], 2)
            pointer += 15
                                                            
            subpackets += parse_packet(binary_transmission[pointer:pointer+sub_packet_length]) + [parse_packet(binary_transmission[pointer+sub_packet_length:])]
        else: # length is 11-bit number representing number of sub-packets
            num_sub_packets = int(binary_transmission[pointer:pointer+11], 2)
            pointer += 11
                                                
            for _ in range(num_sub_packets):
                subpacket, sub_pointer = get_sub_packet(binary_transmission[pointer:])
                subpackets += parse_packet(subpacket)
                pointer += sub_pointer
                
            subpackets += [parse_packet(binary_transmission[pointer:])]
            
        midpoint = 0
        
        for i, x in enumerate(subpackets):
            if not isinstance(x, int):
                midpoint = i
                break
                
        int_values = subpackets[:midpoint]
        padded_value = subpackets[midpoint]
        
        return_val = None
                                                
        if packet_type_id == 0:
            return_val = [sum(int_values)]
        elif packet_type_id == 1:
            return_val = [prod(int_values)]
        elif packet_type_id == 2:
            return_val = [min(int_values)]
        elif packet_type_id == 3:
            return_val = [max(int_values)]
        elif packet_type_id == 5:
            return_val = [1] if subpackets[0] > subpackets[1] else [0]
        elif packet_type_id == 6:
            return_val = [1] if subpackets[0] < subpackets[1] else [0]
        elif packet_type_id == 7:
            return_val = [1] if subpackets[0] == subpackets[1] else [0]
        
        return return_val + padded_value

parse_packet(convert_hex_to_binary(transmission))
# Out:
# [1015320896946]
